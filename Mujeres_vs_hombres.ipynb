# %%
# Mujeres vs Hombres

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('./Gender_Stats_csv/Gender_StatsData.csv')
df.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0        Access to anti-retroviral drugs, female (%)  SH.HIV.ARTC.FE.ZS   NaN
# 1          Access to anti-retroviral drugs, male (%)  SH.HIV.ARTC.MA.ZS   NaN
# 2  Account at a financial institution, female (% ...       WP_time_01.3   NaN
# 3  Account at a financial institution, male (% ag...       WP_time_01.2   NaN
# 4  Adjusted net enrollment rate, primary, female ...     SE.PRM.TENR.FE   NaN
#
#    1961  1962  1963  1964  1965     ...            2008       2009       2010  \
# 0   NaN   NaN   NaN   NaN   NaN     ...        5.611509   7.350393   8.645366
# 1   NaN   NaN   NaN   NaN   NaN     ...        6.393077   7.520210   9.119101
# 2   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN        NaN
# ...

# %%
#df.index=df['Country Code']
#dfClean = df.drop(['Country Code'], axis=1)
dfClean = df.drop(['Country Name'],axis=1)
dfCleanv2 = dfClean.drop(['Indicator Code'], axis=1)
dfCleanv2.head()
# Out:
#   Country Code                                     Indicator Name  1960  1961  \
# 0          ARB        Access to anti-retroviral drugs, female (%)   NaN   NaN
# 1          ARB          Access to anti-retroviral drugs, male (%)   NaN   NaN
# 2          ARB  Account at a financial institution, female (% ...   NaN   NaN
# 3          ARB  Account at a financial institution, male (% ag...   NaN   NaN
# 4          ARB  Adjusted net enrollment rate, primary, female ...   NaN   NaN
#
#    1962  1963  1964  1965  1966  1967     ...            2008       2009  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN     ...        5.611509   7.350393
# 1   NaN   NaN   NaN   NaN   NaN   NaN     ...        6.393077   7.520210
# 2   NaN   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN     ...       81.473801  81.695686
#
# ...

# %%
print(dfCleanv2['Country Code'].unique(),"\n",dfCleanv2['Indicator Name'].unique())
Pais='ARB'
Ind_name= 'Access to anti-retroviral drugs'
# Out:
# ['ARB' 'CSS' 'CEB' 'EAR' 'EAS' 'EAP' 'TEA' 'EMU' 'ECS' 'ECA' 'TEC' 'EUU'
#  'FCS' 'HPC' 'HIC' 'IBD' 'IBT' 'IDB' 'IDX' 'IDA' 'LTE' 'LCN' 'LAC' 'TLA'
#  'LDC' 'LMY' 'LIC' 'LMC' 'MEA' 'MNA' 'TMN' 'MIC' 'NAC' 'OED' 'OSS' 'PSS'
#  'PST' 'PRE' 'SST' 'SAS' 'TSA' 'SSF' 'SSA' 'TSS' 'UMC' 'WLD' 'AFG' 'ALB'
#  'DZA' 'ASM' 'AND' 'AGO' 'ATG' 'ARG' 'ARM' 'ABW' 'AUS' 'AUT' 'AZE' 'BHS'
#  'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BMU' 'BTN' 'BOL' 'BIH' 'BWA'
#  'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'CPV' 'KHM' 'CMR' 'CAN' 'CYM' 'CAF'
#  'TCD' 'CHI' 'CHL' 'CHN' 'COL' 'COM' 'COD' 'COG' 'CRI' 'CIV' 'HRV' 'CUB'
#  'CUW' 'CYP' 'CZE' 'DNK' 'DJI' 'DMA' 'DOM' 'ECU' 'EGY' 'SLV' 'GNQ' 'ERI'
#  'EST' 'ETH' 'FRO' 'FJI' 'FIN' 'FRA' 'PYF' 'GAB' 'GMB' 'GEO' 'DEU' 'GHA'
#  'GIB' 'GRC' 'GRL' 'GRD' 'GUM' 'GTM' 'GIN' 'GNB' 'GUY' 'HTI' 'HND' 'HKG'
#  'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'IMN' 'ISR' 'ITA' 'JAM' 'JPN'
#  'JOR' 'KAZ' 'KEN' 'KIR' 'PRK' 'KOR' 'XKX' 'KWT' 'KGZ' 'LAO' 'LVA' 'LBN'
# ...

# %%
print(Ind_name)
dfSelect=dfCleanv2[dfCleanv2['Indicator Name'].str.contains(Ind_name)]
dfSelect.head()
# Out:
# Access to anti-retroviral drugs
#      Country Code                               Indicator Name  1960  1961  \
# 0             ARB  Access to anti-retroviral drugs, female (%)   NaN   NaN
# 1             ARB    Access to anti-retroviral drugs, male (%)   NaN   NaN
# 628           CSS  Access to anti-retroviral drugs, female (%)   NaN   NaN
# 629           CSS    Access to anti-retroviral drugs, male (%)   NaN   NaN
# 1256          CEB  Access to anti-retroviral drugs, female (%)   NaN   NaN
#
#       1962  1963  1964  1965  1966  1967     ...            2008       2009  \
# 0      NaN   NaN   NaN   NaN   NaN   NaN     ...        5.611509   7.350393
# 1      NaN   NaN   NaN   NaN   NaN   NaN     ...        6.393077   7.520210
# 628    NaN   NaN   NaN   NaN   NaN   NaN     ...       25.755802  31.334186
# 629    NaN   NaN   NaN   NaN   NaN   NaN     ...       15.362094  20.029166
# 1256   NaN   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN
#
# ...

# %%
dfSelect_male=dfSelect[dfSelect['Indicator Name'].str.contains(' male')]
dfSelect_maleC=dfSelect_male.drop('Indicator Name',axis=1)
dfSelect_maleC = dfSelect_maleC.set_index('Country Code')

dfSelect_female=dfSelect[dfSelect['Indicator Name'].str.contains('female')]
dfSelect_femaleC=dfSelect_female.drop('Indicator Name',axis=1)        
dfSelect_femaleC = dfSelect_femaleC.set_index('Country Code')

dfSelect_femaleC.head()
# Out:
#               1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# Country Code
# ARB            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# CSS            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# CEB            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# EAR            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# EAS            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                  ...            2008       2009       2010       2011  \
# Country Code     ...
# ARB              ...        5.611509   7.350393   8.645366  10.059527
# CSS              ...       25.755802  31.334186  33.662448  37.140360
# CEB              ...             NaN        NaN        NaN        NaN
# EAR              ...       12.134046  17.600484  24.080326  31.044632
# EAS              ...             NaN        NaN        NaN        NaN
#
# ...

# %%
tt=dfSelect_femaleC.T
tt.index
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', 'Unnamed: 61'],
#       dtype='object')

# %%
new_index=[]
for indice in tt.index:
    try:
        new_index.append(int(indice))
    except:
        new_index.append(2017)
    
tt.index=new_index
print(tt.index)
# Out:
# Int64Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#             1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#             1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#             1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#             2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#             2015, 2016, 2017],
#            dtype='int64')

# %%
ax=tt.plot(figsize=(15,15))
ax.set_xlim(2000,2016)
plt.show()

# %%
tt.head()
# Out:
# Country Code  ARB  CSS  CEB  EAR  EAS  EAP  TEA  EMU  ECS  ECA ...   URY  UZB  \
# 1960          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 1961          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 1962          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 1963          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 1964          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#
# Country Code  VUT  VEN  VNM  VIR  PSE  YEM  ZMB  ZWE
# 1960          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1961          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1962          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1963          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1964          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 263 columns]

# %%
plt.figure(figsize=(8,5), dpi=100)
paises=[]
for keys in tt:
    if np.any(tt[keys].values > 70):
        
        plt.plot(tt[keys].index,tt[keys].values,label=keys)
        paises.append(keys)
        
plt.legend(loc='upper left', frameon=False)
plt.show()

# %%
mm=dfSelect_maleC.T
mm.index
new_index=[]
for indice in mm.index:
    try:
        new_index.append(int(indice))
    except:
        new_index.append(2017)
    
mm.index=new_index

plt.figure(figsize=(8,5), dpi=100)
paises=[]
for keys in mm:        
      if np.any(mm[keys].values > 70):
        plt.plot(mm[keys].index,mm[keys].values,label=keys)
        paises.append(keys)
        
plt.legend(loc='upper left', frameon=False)
plt.show()
